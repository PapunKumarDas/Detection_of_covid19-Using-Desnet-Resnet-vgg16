# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pickle
from sklearn.svm import SVC

# %%
Categories=['Covid19 Negative','Covid19 Positive']
flat_data_arr=[] #input array
target_arr=[] #output array
datadir='dataset' 
#path which contains all the categories of images

for i in Categories:
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(150,150,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(Categories.index(i))
    
    print(f'loaded category:{i} successfully')
    
flat_data=np.array(flat_data_arr)
target=np.array(target_arr)
df=pd.DataFrame(flat_data) #dataframe
df['Target']=target
x=df.iloc[:,:-1] #input data 
y=df.iloc[:,-1] #output data
df
# Out:
# loading... category : Covid19 Negative
# loaded category:Covid19 Negative successfully
# loading... category : Covid19 Positive
# loaded category:Covid19 Positive successfully
#               0         1         2         3         4         5         6  \
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1      0.037059  0.037059  0.037059  0.035295  0.035295  0.035295  0.035294
# 2      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3      0.000000  0.000000  0.000000  0.000001  0.000001  0.000001  0.007047
# 4      0.595817  0.595817  0.595817  0.568314  0.568314  0.568314  0.539852
# ...         ...       ...       ...       ...       ...       ...       ...
# 13803  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13804  0.334890  0.334890  0.334890  0.324703  0.324703  0.324703  0.321050
# 13805  0.068289  0.068289  0.068289  0.001731  0.001731  0.001731  0.000100
# 13806  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13807  0.586985  0.586985  0.586985  0.388602  0.388602  0.388602  0.400460
#
#               7         8         9  ...     67491     67492     67493  \
# 0      0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1      0.035294  0.035294  0.035294  ...  0.238969  0.238969  0.238969
# 2      0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 3      0.007047  0.007047  0.060230  ...  0.000000  0.000000  0.000000
# 4      0.539852  0.539852  0.516311  ...  0.013790  0.013790  0.013790
# ...         ...       ...       ...  ...       ...       ...       ...
# 13803  0.000000  0.000000  0.000000  ...  0.551500  0.551500  0.551500
# 13804  0.321050  0.321050  0.318537  ...  0.871053  0.871053  0.871053
# 13805  0.000100  0.000100  0.000195  ...  0.487368  0.487368  0.487368
# 13806  0.000000  0.000000  0.000000  ...  0.249863  0.249863  0.249863
# 13807  0.400460  0.400460  0.398469  ...  0.767136  0.767136  0.767136
#
#           67494     67495     67496     67497     67498     67499  Target
# 0      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000       0
# 1      0.313117  0.313117  0.313117  0.397714  0.397714  0.397714       0
# 2      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000       0
# 3      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000       0
# 4      0.019615  0.019615  0.019615  0.019796  0.019796  0.019796       0
# ...         ...       ...       ...       ...       ...       ...     ...
# 13803  0.541967  0.541967  0.541967  0.538057  0.538057  0.538057       1
# 13804  0.848351  0.848351  0.848351  0.888237  0.888237  0.888237       1
# 13805  0.582182  0.582182  0.582182  0.605993  0.605993  0.605993       1
# 13806  0.241874  0.241874  0.241874  0.227179  0.227179  0.227179       1
# 13807  0.739276  0.739276  0.739276  0.811038  0.811038  0.811038       1
#
# [13808 rows x 67501 columns]

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100],'gamma':[0.0001,0.001,0.1,1],'kernel':['rbf','poly']}
svc=svm.SVC(probability=True)
model=GridSearchCV(svc,param_grid)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=77,stratify=y)
# print(x_train.__sizeof__)
np.size(x_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:1609: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:1609: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# 699030000

# %%
model=SVC(C=1,kernel='poly',gamma='auto',probability=True)
print('Splitted Successfully')
model.fit(x_train,y_train)
print('The Model is trained well with the given images')
# model.best_params_ contains the best parameters obtained from GridSearchCV

pick=open('model.sav','wb')
pickle.dump(model,pick)
pick.close()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:1609: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# C:\Users\user\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\model_selection\_split.py:1609: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# Splitted Successfully
# The Model is trained well with the given images

# %%
y_pred=model.predict(x_test)
print("The predicted Data is :")
print(y_pred)
print("The actual data is:")
print(np.array(y_test))
print(f"The model is {accuracy_score(y_pred,y_test)*100}% accurate")
# Out:
# The predicted Data is :
# [0 0 0 ... 0 1 0]
# The actual data is:
# [0 1 0 ... 0 1 1]
# The model is 76.071842410197% accurate
