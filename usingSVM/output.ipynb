# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import pickle
from sklearn.svm import SVC

# %%
pick=open('model.sav','rb')
model=pickle.load(pick)
pick.close()

# %%
url=input('Enter URL of Image :')

# %%
url='D:\\SVM2\\dataset\\Covid19 Negative\\NORMAL-4.png'
Categories=['Covid19 Negative','Covid19 Positive']
img=imread(url)
plt.imshow(img)
plt.show()
plt.imshow(img,cmap='gray',vmin=0,vmax=390)
plt.show

img_resize=resize(img,(150,150,3))
l=[img_resize.flatten()]
probability=model.predict_proba(l)

for ind,val in enumerate(Categories):
    print(f'{val} = {probability[0][ind]*100}%')
if probability[0][0]*100 >probability[0][1]*100:
    print('negative')
else:
    print('possitive')

# print("The predicted image is : "+Categories[model.predict(l)[0]])
# Out:
# Covid19 Negative = 89.57443205936482%
# Covid19 Positive = 10.425567940635162%
# negative
